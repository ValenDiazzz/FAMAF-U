# %% [markdown]
# ### **TAREA 0**
#
# En  esta tarea vas a tener que realizar dos ejercicios del ["Curso acelerado de introducción a CS"](https://studio.code.org/s/20-hour) de code.org
#
# La tarea debe entregarse en este mismo documento.
#
# Una vez que termines de hacer cada ejercicio hacé una captura de pantalla de la solución y subila desde un archivo usando el ícono ![image.png](data:image/png;base64,...) o ponela en el portapapeles y pegala haciendo Control-v
#
# **Importante:** Tanto en el ejercicio 1 como el 2,  es conveniente hacer toda la secuencia de ejercicios que propone la lección. Esto te va a permitir ir aprendiendo poco a poco métodos para resolver este tipo de ejercicios.

# %% [markdown]
# **Ejercicio 1:** Resolvé el ejercicio 8 de la lección 11 (https://studio.code.org/s/20-hour/stage/11/puzzle/8) usando _un solo bloque verde_ y pegá la solución más abajo (en esta celda).

# %% [markdown]
# ![Captura de pantalla (69).png](data:image/png;base64,...)

# %% [markdown]
# **Ejercicio 2:** Resolvé el  ejercicio 10 de la lección 13 (https://studio.code.org/s/20-hour/stage/13/puzzle/10) y pegá la solución más abajo (en esta celda).

# %% [markdown]
# ![Captura de pantalla (66).png](data:image/png;base64,...)

# %% [markdown]
# **Actividad adicional**
#
# Para practicar para las próximas tareas vamos hacer un ejercicio en código Python.
#
# Para imprimir en pantalla la expresión `¡Hola!` en Python se escribe en una ventana de código simplemente
#
#         print('¡Hola!')
#
# o también
#
#         print("¡Hola!")
#
# y luego lo ejecutamos clicando ![image.png](data:image/png;base64,...).
#
# Probá la siguiente celda de código:

# %%
print('¡Hola!')

# %% [markdown]
# **Ejercicio 3**
#
# Imprimí en pantalla `¡Adios!`

# %%
# Escribí tu código abajo de esta linea
print('¡Adios!')
