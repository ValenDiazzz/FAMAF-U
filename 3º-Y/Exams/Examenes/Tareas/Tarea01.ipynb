# %% [markdown]
# ### **TAREA 1**
#
# En  esta tarea vas a tener que realizar dos ejercicios de programación en Python.
#
# **Importante 1**
# - La tarea debe entregarse en este archivo, completando las celdas de código correspondientes.
# - Al clicar "Ejecutar celda" (el triangulito blanco) en la celda correspondiente se debería dibujar lo solicitado en el ejercicio.
#
# **Importante 2**
# - No olvides organizar tu programa incluyendo comentarios, espacios y sangrías de manera adecuada.
# - Evitar la utilización de funciones sofisticadas de Python.
# - Evitar la utilización de mecanismos de iteración diferentes a
# ```
# for _ in range...
# ```

# %% [markdown]
# Antes de comenzar con tus soluciones debés instalar ColabTurtle e importar sus funciones:

# %%
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *
# Out:
# Collecting ColabTurtle
#   Downloading https://files.pythonhosted.org/packages/08/6f/619066317c24cd988979ad1b8c7b324c09ee1c408bfd88926889d6a62d99/ColabTurtle-2.1.0.tar.gz
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-cp37-none-any.whl size=7661 sha256=c8d9ff71a6bd0de8b4cc000a02e575e9ea22d0357346cae3db5386cf048f1b0e
#   Stored in directory: /root/.cache/pip/wheels/df/e9/3f/df3fccd8971c5473dc0c6450984cd057de8c9a1271069ebf18
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.1.0

# %% [markdown]
# **Ejercicio 1:** Traducí a Python tu solución al ejercicio 9 de la lección 5 (https://studio.code.org/s/20-hour/stage/5/puzzle/9) y agregale lo necesario para que realice el siguiente dibujo
#
# ![image.png](data:image/png;base64,...)
#
# Para ello, observá que:
#
# *   La circunferencia que se dibujó mide ```360```.
# *   Por lo tanto su diámetro mide 360/pi y su radio 180/pi
# *   Podés escribir instrucciones como `forward(360/math.pi)`, también se puede usar `penup()` para desplazarse sin dibujar y luego `pendown()` para volver a dibujar.
#
# Podés ejecutar:

# %%
# Escribí tu código abajo de esta linea

#Bibliotecas
from ColabTurtle.Turtle import *
from math import pi
initializeTurtle()

#Setup de estética
bgcolor("yellow")
pensize(3)
color("green")
speed (8)

#Comienzo de la tarea

#Dibujo del cuadraro
for _ in range (4):
    forward(360/pi)
    right(90)

forward(180/pi)

#Dibujo del círculo
color("black")
for _ in range(360):
    forward(1)
    right(1)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="yellow"/>
#         <line x1="400" y1="250" x2="400.0" y2="135.408" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="400.0" y1="135.408" x2="514.592" y2="135.408" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="514.592" y1="135.408" x2="514.592" y2="250.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="514.592" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="400.0" y1="250.0" x2="400.0" y2="192.704" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="400.0" y1="192.704" x2="400.0" y2="191.704" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.0" y1="191.704" x2="400.017" y2="190.704" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.017" y1="190.704" x2="400.052" y2="189.705" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.052" y1="189.705" x2="400.104" y2="188.706" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.104" y1="188.706" x2="400.174" y2="187.708" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.174" y1="187.708" x2="400.261" y2="186.712" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.261" y1="186.712" x2="400.366" y2="185.717" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.366" y1="185.717" x2="400.488" y2="184.724" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.488" y1="184.724" x2="400.627" y2="183.734" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.627" y1="183.734" x2="400.783" y2="182.746" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.783" y1="182.746" x2="400.957" y2="181.761" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.957" y1="181.761" x2="401.148" y2="180.779" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="401.148" y1="180.779" x2="401.356" y2="179.801" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="401.356" y1="179.801" x2="401.581" y2="178.827" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="401.581" y1="178.827" x2="401.823" y2="177.857" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="401.823" y1="177.857" x2="402.082" y2="176.891" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="402.082" y1="176.891" x2="402.358" y2="175.93" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="402.358" y1="175.93" x2="402.65" y2="174.974" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="402.65" y1="174.974" x2="402.959" y2="174.023" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="402.959" y1="174.023" x2="403.285" y2="173.077" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="403.285" y1="173.077" x2="403.627" y2="172.137" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="403.627" y1="172.137" x2="403.985" y2="171.203" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="403.985" y1="171.203" x2="404.36" y2="170.276" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="404.36" y1="170.276" x2="404.751" y2="169.355" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="404.751" y1="169.355" x2="405.158" y2="168.441" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="405.158" y1="168.441" x2="405.581" y2="167.535" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="405.581" y1="167.535" x2="406.019" y2="166.636" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="406.019" y1="166.636" x2="406.473" y2="165.745" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="406.473" y1="165.745" x2="406.942" y2="164.862" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="406.942" ...

# %% [markdown]
# **Ejercicio 2:** Traducí a Python tu solución al ejercicio 8 de la lección 7 (https://studio.code.org/s/20-hour/stage/7/puzzle/8).

# %%
# Escribí tu código abajo de esta linea

#Bibliotecas
from random import choice
initializeTurtle()

#Setup de estética
bgcolor("yellow")
pensize(3)
speed(10)

#Tarea a realizar
for var1 in range (4):
    for var2 in range (10):
        color(choice(['orange', 'red', 'green', 'blue', 'purple', 'grey', 'black']))
        for var3 in range (4):
            forward(20)
            right(90)
        forward(20)    
    right(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="yellow"/>
#         <line x1="400" y1="250" x2="400.0" y2="230.0" stroke-linecap="round" style="stroke:grey;stroke-width:3"/><line x1="400.0" y1="230.0" x2="420.0" y2="230.0" stroke-linecap="round" style="stroke:grey;stroke-width:3"/><line x1="420.0" y1="230.0" x2="420.0" y2="250.0" stroke-linecap="round" style="stroke:grey;stroke-width:3"/><line x1="420.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:grey;stroke-width:3"/><line x1="400.0" y1="250.0" x2="400.0" y2="230.0" stroke-linecap="round" style="stroke:grey;stroke-width:3"/><line x1="400.0" y1="230.0" x2="400.0" y2="210.0" stroke-linecap="round" style="stroke:grey;stroke-width:3"/><line x1="400.0" y1="210.0" x2="420.0" y2="210.0" stroke-linecap="round" style="stroke:grey;stroke-width:3"/><line x1="420.0" y1="210.0" x2="420.0" y2="230.0" stroke-linecap="round" style="stroke:grey;stroke-width:3"/><line x1="420.0" y1="230.0" x2="400.0" y2="230.0" stroke-linecap="round" style="stroke:grey;stroke-width:3"/><line x1="400.0" y1="230.0" x2="400.0" y2="210.0" stroke-linecap="round" style="stroke:grey;stroke-width:3"/><line x1="400.0" y1="210.0" x2="400.0" y2="190.0" stroke-linecap="round" style="stroke:red;stroke-width:3"/><line x1="400.0" y1="190.0" x2="420.0" y2="190.0" stroke-linecap="round" style="stroke:red;stroke-width:3"/><line x1="420.0" y1="190.0" x2="420.0" y2="210.0" stroke-linecap="round" style="stroke:red;stroke-width:3"/><line x1="420.0" y1="210.0" x2="400.0" y2="210.0" stroke-linecap="round" style="stroke:red;stroke-width:3"/><line x1="400.0" y1="210.0" x2="400.0" y2="190.0" stroke-linecap="round" style="stroke:red;stroke-width:3"/><line x1="400.0" y1="190.0" x2="400.0" y2="170.0" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.0" y1="170.0" x2="420.0" y2="170.0" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="420.0" y1="170.0" x2="420.0" y2="190.0" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="420.0" y1="190.0" x2="400.0" y2="190.0" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.0" y1="190.0" x2="400.0" y2="170.0" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.0" y1="170.0" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:purple;stroke-width:3"/><line x1="400.0" y1="150.0" x2="420.0" y2="150.0" stroke-linecap="round" style="stroke:purple;stroke-width:3"/><line x1="420.0" y1="150.0" x2="420.0" y2="170.0" stroke-linecap="round" style="stroke:purple;stroke-width:3"/><line x1="420.0" y1="170.0" x2="400.0" y2="170.0" stroke-linecap="round" style="stroke:purple;stroke-width:3"/><line x1="400.0" y1="170.0" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:purple;stroke-width:3"/><line x1="400.0" y1="150.0" x2="400.0" y2="130.0" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.0" y1="130.0" x2="420.0" y2="130.0" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="420.0" y1="130.0" x2="420.0" y2="150.0" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="420.0" y1="150.0" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.0" y1="150.0" x2="400.0" y2="130.0" stroke-linecap="round" style="stroke:black;stroke-width:3"/><line x1="400.0" y1="130.0" x2="400.0" y2="110.0" stroke-linecap="round" style="stroke:red;stroke-width:3"/><line x1="400.0" y1="110.0" x2="420.0" y2="110.0" stroke-linecap="round" style="stroke:red;stroke-width:3"/><line x1="420.0" y1="110.0" x2="420.0" y2="130.0" stroke-linecap="round" style="stroke:red;stroke-width:3"/><line x1="420.0" y1="130.0" x2="400.0" y2="130.0" stroke-linecap="round" style="stroke:red;stroke-width:3"/><line x1="400.0" y1="130.0" x2="400.0" y2="110.0" stroke-linecap="round" style="stroke:red;stroke-width:3"/><line x1="400.0" y1="110.0" x2="400.0" y2="90.0" stroke-linecap="round" style="stroke:green;stroke-width:3"/><line x1="400.0" y1="90.0" x2="420.0" y2="90.0" stroke-linecap ...
